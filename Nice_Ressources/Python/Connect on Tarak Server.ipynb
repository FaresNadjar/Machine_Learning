# %%
import pymongo
#Connect to local host
#myclient=pymongo.MongoClient("mongodb://localhost:27017/")
#Connect to Tarak's Server
myclient=pymongo.MongoClient("mongodb://reader:miWB2TM4@51.68.214.156:27017/") # defaults to port 27017

# %%
myclient.list_database_names()
# Out:
# ['RealAnalyticsData_prod',
#  'admin',
#  'config',
#  'local',
#  'mapping',
#  'opta',
#  'playersImpactSimulation',
#  'sofifa']

# %%
mydb = myclient['opta']

# %%
mydb.list_collection_names()
# Out:
# ['Fixture']

# %%
mycol=mydb['GameDRLTraining']

# %%
c=0
for i in mycol.find({'gameId':692816},{'_id':0,'reward_lt_discounted':0,'adjusted_reward':0}).sort('eventId') :
    print(i)
    c+=1
    print()
# Out:
# {'eventId': 1360648, 'typeId': 1.0, 'gameId': 692816, 'reward': 0.0, 'reward_lt_fl': 0.0, 'action': 'pass', 'terminal': 0.0, 'current_state': [{'x': 0.995, 'y': 0.009, 'gameTimeRemain': 0.82393617, 'scoreDiff': 0.625, 'manPower': 0.5, 'duration': 0.0, 'outcome': 1.0, 'home_away': 1.0, 'interrupted': 0.0, 'distance': 0.305464665, 'angle': 0.000493901, 'is_attacking': 1.0, 'lt': 0.0, 'action__ball_lost': 0.0, 'action__ball_recovery': 0.0, 'action__blocked_shot': 0.0, 'action__challenge': 0.0, 'action__claim': 0.0, 'action__clearance': 0.0, 'action__cross': 1.0, 'action__dangerous_foul_obtained': 0.0, 'action__error': 0.0, 'action__fk_shot': 0.0, 'action__foul': 0.0, 'action__pass': 0.0, 'action__penalty_save': 0.0, 'action__penalty_shot': 0.0, 'action__pick_up': 0.0, 'action__punch': 0.0, 'action__run_with_ball': 0.0, 'action__save': 0.0, 'action__shot': 0.0, 'action__skill': 0.0, 'action__smother': 0.0, 'action__back_in_play': 0.0, 'action__clean_recovery': 0.0, 'action__quick_recover
# ...

# %%
mycol.count_documents({'gameId':692816})
# Out:
# 1458
# Traceback (most recent call last):
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py", line 1530, in _process_periodic_tasks
#     cursor_ids, address, topology, session=None)
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/mongo_client.py", line 1460, in _kill_cursors
#     server = topology.select_server_by_address(tuple(address))
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/topology.py", line 249, in select_server_by_address
#     address)
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/topology.py", line 226, in select_server
#     address))
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/topology.py", line 184, in select_servers
#     selector, server_timeout, address)
#   File "/home/fares/anaconda3/lib/python3.7/site-packages/pymongo/topology.py", line 200, in _select_servers_loop
#     self._error_message(selector))
# ...
